# %%
# %matplotlib notebook
import matplotlib.pyplot as plt

import numpy as np
import pandas as pd

# train_loss for cnn with shuffle=True
cross_validation = {"cross_validation": [0.695, 0.604, 0.361, 0.179, 0.114, 
                                             0.094, 0.074, 0.063, 0.052, 0.047, 
                                             0.037, 0.031, 0.025, 0.021, 0.016, 
                                             0.012, 0.010, 0.008, 0.007, 0.005]}

# train_loss for cnn with shuffle=False
train_test_split = {"train_test_split":[0.679, 0.590, 0.346, 0.166, 0.122, 0.095, 0.077, 0.061, 0.052, 
                                        0.043, 0.036, 0.030, 0.026, 0.023, 0.018, 0.014, 0.011, 0.009, 0.007, 0.005]}


################################# f1 #################################
# 20 epochs for cnn with shuffle=True
cnn_t =  {"CNN with shuffle=True": [0.5646, 0.8333, 0.9108, 0.9379, 0.9528, 
       0.9574, 0.9636, 0.9636,  0.9641, 0.9708, 
       0.9682, 0.9703, 0.9708, 0.9718, 0.9682, 
       0.9703, 0.9687, 0.9687, 0.9682, 0.9667]}

# 20 epochs for cnn with shuffle=False     def get_train(self): return self.__get_data('train.json', shuffle=False)
cnn_f =  {"CNN with shuffle=False": [0.5646, 0.8169, 0.9041, 0.9431, 0.9533, 
       0.9559, 0.9574, 0.9615,  0.9641, 0.9677, 
       0.9697, 0.9697, 0.9692, 0.9687, 0.9703, 
       0.9708, 0.9703, 0.9677, 0.9682, 0.9677]}

# 20 iteration for baseline with cross_validation
base1 = {"baseline with cross_validation": [0.55140187, 0.57943925, 0.57943925, 0.55140187, 0.62616822,
                           0.52336449, 0.5046729 , 0.4953271 , 0.59813084, 0.57943925, 
                           0.50943396, 0.50943396, 0.58490566, 0.54716981, 0.63207547, 
                           0.55660377, 0.54716981, 0.50943396, 0.56603774, 0.50943396]}


# 20 iteration for baseline with RepeatedKFold
base2 = {"baseline with RepeatedKFold": [0.5652582159624413, 0.577909887359199, 0.5722778473091364, 0.5666458072590739, 
                                         0.5691489361702128, 0.5688360450563203, 0.5766583229036295, 0.5757196495619524, 
                                         0.5672715894868585, 0.5735294117647058, 0.5715179968701095, 0.568523153942428, 
                                         0.5704005006257822, 0.5700876095118899, 0.564142678347935, 0.5732165206508135, 
                                         0.5647684605757196, 0.5741551939924906, 0.5794743429286608, 0.5747809762202754]}

# %%
F1_Score = pd.DataFrame(cnn_t)
cnn_f = pd.DataFrame(cnn_f)
base1 = pd.DataFrame(base1)
base2 = pd.DataFrame(base2)
F1_Score['CNN with shuffle=False'] = cnn_f
F1_Score['baseline with cross_validation'] = base1
F1_Score['baseline with RepeatedKFold'] = base2

# %%
F1_Score.plot()
# Out:
# <img src="data:image/png;base64,..." width="638">
# <AxesSubplot:>

# %%
# performance on test data

# cnn for test set with shuffle
Test_loss_t = 0.101
CNN_t = 0.9718

# cnn for test set without shuffle
Test_loss_f = 0.105
CNN_f = 0.9708

# baseline
cv = 0.5384615384615384
Re_KFold = 0.5352112676056338

# %%
name_list = ['CNN','baseline with cv','baseline with Re_KFold']
num_list = [0.9718, 0.5384615384615384, 0.5384615384615384]
num_list1 = [0.9708, 0.5123076923076924, 0.5123076923076924]
x =list(range(len(num_list)))
total_width, n = 0.8, 2
width = total_width / n
fig = plt.figure()
plt.bar(x, num_list, width=width, label='using cross validation', fc = 'g')
for i in range(len(x)):
    x[i] = x[i] + width
plt.bar(x, num_list1, width=width, label='without cross validation', tick_label = name_list, fc = 'r')
plt.legend()
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="638">

# %% [raw]
# Cross-validation can improve the performance of baseline, but can not provide an effective improvement for the CNN model.
# Hence, we come to a conclusion that cross-validation is only useful under the following situations:
# 1. The model is under-fitting (the model is too easy).
# 2. The dataset is too small.
# 3. The distribution of data is un-uniform.
